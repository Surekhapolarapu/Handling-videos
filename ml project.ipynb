# %%
import numpy as np
import pandas as pd
import os
import cv2
import re

# %%
os.mkdir(r"C:\Users\laksh\Downloads\Animation")136,22,17
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 os.mkdir(r"C:\Users\laksh\Downloads\Animation")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\laksh\\Downloads\\Animation'

# %%
img = cv2.imread(r"C:\Users\laksh\Downloads\prj image.jpg")

# %%
x1 = -1
y1 = -1
def mouse_tracking(event, x, y, flags, param):
    global x1, y1
    if event == 1 :
        x1 = x
        y1 = y
    #elif event == 2 :
          #cv2.line(img,(x1,y1),(x,y),(0,0,0),2)
           #cv2.circle(img,(x,y),5,(277,178,10),-1)
        #cv2.circle(img,(x,y),5,(255,255,255),-1)
        
    elif event ==2:
    
          #cv2.circle(img,(x,y),5,(20,0,255),-1)
         # cv2.circle(img,(x,y),5,(255,0,0),-1)
          #cv2.circle(img,(x,y),20,(136,22,17),-1)
          #cv2.rectangle(img,(x1,y1),(x,y),(18,4,89),-1)
          cv2.putText(img,"Innomatics Research Labs",(150,200),cv2.FONT_HERSHEY_COMPLEX,1,(105,16,122),4)
          cv2.putText(img,"Credits :",(75,400),cv2.FONT_HERSHEY_COMPLEX,1,(122,17,16),4)
          cv2.putText(img,"Priyanka ",(75,440),cv2.FONT_HERSHEY_COMPLEX,1,(59,31,146),1)
          cv2.putText(img,"Surekha ",(75,480),cv2.FONT_HERSHEY_COMPLEX,1,(59,31,146),1)
          cv2.putText(img,"shaik.afroz",(75,520),cv2.FONT_HERSHEY_COMPLEX,1,(59,31,146),1)
          cv2.putText(img,"VAMSHI",(75,560),cv2.FONT_HERSHEY_COMPLEX,1,(59,31,146),1)
        
          cv2.putText(img,"Guided by :",(400,400),cv2.FONT_HERSHEY_COMPLEX,1,(87,46,40),4)
          cv2.putText(img,"Saxon K Sha",(400,440),cv2.FONT_HERSHEY_COMPLEX,1,(59,31,146),1)
          cv2.putText(img,"Lakshmi Teja Illuri",(400,480),cv2.FONT_HERSHEY_COMPLEX,1,(59,31,146),1)
          cv2.putText(img,"Lakshmi Vangapandu",(400,520),cv2.FONT_HERSHEY_COMPLEX,1,(59,31,146),1)

# %%
cv2.namedWindow("mouse tracking",flags = cv2.WINDOW_FREERATIO)
cv2.setMouseCallback("mouse tracking", mouse_tracking)
c=237

black_image =  np.zeros((1000,1000,3),dtype=np.uint8)

while True:
    cv2.imshow("mouse tracking",img)
    if cv2.waitKey(1) & 255 ==ord("s"):
        cv2.imwrite(r"C:\Users\laksh\Downloads\Animation\{}.jpg".format(c),img)
        print("image is captured")
        c=c+1
    if cv2.waitKey(1) & 255 == ord("q"):
        break
cv2.destroyAllWindows()
# Out:
# image is captured
# image is captured
# image is captured

# %%
img
# Out:
# array([[[233, 207, 130],
#         [237, 210, 136],
#         [229, 201, 137],
#         ...,
#         [231, 208, 133],
#         [231, 206, 136],
#         [229, 207, 136]],
#
#        [[235, 206, 131],
#         [232, 205, 131],
#         [240, 210, 145],
#         ...,
#         [232, 207, 135],
#         [231, 207, 135],
#         [231, 207, 135]],
#
#        [[239, 207, 134],
#         [237, 205, 134],
#         [232, 200, 134],
#         ...,
#         [234, 205, 136],
#         [234, 206, 135],
#         [234, 207, 133]],
#
#        ...,
#
#        [[169, 169, 169],
#         [169, 169, 169],
#         [169, 169, 169],
#         ...,
#         [169, 169, 169],
#         [169, 169, 169],
#         [169, 169, 169]],
#
#        [[169, 169, 169],
#         [169, 169, 169],
#         [169, 169, 169],
#         ...,
#         [169, 169, 169],
#         [169, 169, 169],
#         [169, 169, 169]],
#
#        [[169, 169, 169],
#         [169, 169, 169],
#         [169, 169, 169],
#         ...,
#         [169, 169, 169],
#         [169, 169, 169],
#         [169, 169, 169]]], dtype=uint8)

# %%
frames = os.listdir(r"C:\Users\laksh\Downloads\animation")

# %%
frames
# Out:
# ['101.jpg',
#  '102.jpg',
#  '103 - Copy.jpg',
#  '103.jpg',
#  '104.jpg',
#  '105.jpg',
#  '106.jpg',
#  '107.jpg',
#  '109.jpg',
#  '110.jpg',
#  '111.jpg',
#  '112.jpg',
#  '113.jpg',
#  '114.jpg',
#  '115.jpg',
#  '116.jpg',
#  '118.jpg',
#  '119.jpg',
#  '125.jpg',
#  '126.jpg',
#  '127.jpg',
#  '128.jpg',
#  '129.jpg',
#  '130.jpg',
#  '140.jpg',
#  '141.jpg',
#  '142.jpg',
#  '143.jpg',
#  '144.jpg',
#  '145.jpg',
#  '147.jpg',
#  '148.jpg',
#  '149.jpg',
#  '150.jpg',
#  '151.jpg',
#  '152.jpg',
#  '153.jpg',
#  '154.jpg',
#  '155.jpg',
#  '156.jpg',
#  '157.jpg',
#  '158.jpg',
#  '160.jpg',
#  '161.jpg',
#  '162.jpg',
#  '164.jpg',
#  '165.jpg',
#  '166.jpg',
#  '17.jpg',
#  '18.jpg',
#  '187.jpg',
#  '188.jpg',
#  '189.jpg',
#  '19.jpg',
#  '190.jpg',
#  '191.jpg',
#  '192.jpg',
#  '193.jpg',
#  '194.jpg',
#  '195.jpg',
#  '196.jpg',
#  '197.jpg',
#  '198.jpg',
#  '199.jpg',
#  '200.jpg',
#  '201.jpg',
#  '202.jpg',
#  '203.jpg',
#  '204.jpg',
#  '205.jpg',
#  '206.jpg',
#  '207.jpg',
#  '208.jpg',
#  '209.jpg',
#  '210.jpg',
#  '211.jpg',
#  '212.jpg',
#  '213.jpg',
#  '214.jpg',
#  '215.jpg',
#  '216.jpg',
#  '217.jpg',
#  '218.jpg',
#  '219.jpg',
#  '22.jpg',
#  '220.jpg',
#  '221.jpg',
#  '222.jpg',
#  '223.jpg',
#  '224.jpg',
#  '225.jpg',
#  '226.jpg',
#  '227.jpg',
#  '228.jpg',
#  '229.jpg',
#  '23.jpg',
#  '230.jpg',
#  '231.jpg',
#  '232.jpg',
#  '233.jpg',
#  '234.jpg',
#  '235.jpg',
#  '236.jpg',
#  '237.jpg',
#  '238.jpg',
#  '239.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '31.jpg',
#  '32.2.jpg',
#  '32.jpg',
#  '33.jpg',
#  '34.jpg',
#  '35.jpg',
#  '36.jpg',
#  '37.jpg',
#  '38.jpg',
#  '39 - Copy.jpg',
#  '39.jpg',
#  '40.jpg',
#  '41.3.jpg',
#  '41.4.jpg',
#  '41.jpg',
#  '42.jpg',
#  '43.jpg',
#  '58.jpg',
#  '59.jpg',
#  '60.jpg',
#  '84.jpg',
#  '85.jpg',
#  '86.jpg',
#  '87.jpg',
#  '88.jpg',
#  '89.jpg',
#  '90.jpg',
#  '91.jpg',
#  '92.jpg',
#  '93.jpg',
#  '94.jpg',
#  '95.jpg',
#  '96.jpg',
#  '97.jpg',
#  '98.2.jpg',
#  '98.3.jpg',
#  '98.4.jpg',
#  '98.jpg',
#  '99.jpg',
#  'output_video.mp4']

# %%
import re
frame_file = [f for f in frames if f.endswith(('.jpg'))]
frame_file.sort(key=lambda x: int(re.findall(r'\d+', os.path.splitext(x)[0])[0]))

# %%
frame_file
# Out:
# ['17.jpg',
#  '18.jpg',
#  '19.jpg',
#  '22.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '31.jpg',
#  '32.2.jpg',
#  '32.jpg',
#  '33.jpg',
#  '34.jpg',
#  '35.jpg',
#  '36.jpg',
#  '37.jpg',
#  '38.jpg',
#  '39 - Copy.jpg',
#  '39.jpg',
#  '40.jpg',
#  '41.3.jpg',
#  '41.4.jpg',
#  '41.jpg',
#  '42.jpg',
#  '43.jpg',
#  '58.jpg',
#  '59.jpg',
#  '60.jpg',
#  '84.jpg',
#  '85.jpg',
#  '86.jpg',
#  '87.jpg',
#  '88.jpg',
#  '89.jpg',
#  '90.jpg',
#  '91.jpg',
#  '92.jpg',
#  '93.jpg',
#  '94.jpg',
#  '95.jpg',
#  '96.jpg',
#  '97.jpg',
#  '98.2.jpg',
#  '98.3.jpg',
#  '98.4.jpg',
#  '98.jpg',
#  '99.jpg',
#  '101.jpg',
#  '102.jpg',
#  '103 - Copy.jpg',
#  '103.jpg',
#  '104.jpg',
#  '105.jpg',
#  '106.jpg',
#  '107.jpg',
#  '109.jpg',
#  '110.jpg',
#  '111.jpg',
#  '112.jpg',
#  '113.jpg',
#  '114.jpg',
#  '115.jpg',
#  '116.jpg',
#  '118.jpg',
#  '119.jpg',
#  '125.jpg',
#  '126.jpg',
#  '127.jpg',
#  '128.jpg',
#  '129.jpg',
#  '130.jpg',
#  '140.jpg',
#  '141.jpg',
#  '142.jpg',
#  '143.jpg',
#  '144.jpg',
#  '145.jpg',
#  '147.jpg',
#  '148.jpg',
#  '149.jpg',
#  '150.jpg',
#  '151.jpg',
#  '152.jpg',
#  '153.jpg',
#  '154.jpg',
#  '155.jpg',
#  '156.jpg',
#  '157.jpg',
#  '158.jpg',
#  '160.jpg',
#  '161.jpg',
#  '162.jpg',
#  '164.jpg',
#  '165.jpg',
#  '166.jpg',
#  '187.jpg',
#  '188.jpg',
#  '189.jpg',
#  '190.jpg',
#  '191.jpg',
#  '192.jpg',
#  '193.jpg',
#  '194.jpg',
#  '195.jpg',
#  '196.jpg',
#  '197.jpg',
#  '198.jpg',
#  '199.jpg',
#  '200.jpg',
#  '201.jpg',
#  '202.jpg',
#  '203.jpg',
#  '204.jpg',
#  '205.jpg',
#  '206.jpg',
#  '207.jpg',
#  '208.jpg',
#  '209.jpg',
#  '210.jpg',
#  '211.jpg',
#  '212.jpg',
#  '213.jpg',
#  '214.jpg',
#  '215.jpg',
#  '216.jpg',
#  '217.jpg',
#  '218.jpg',
#  '219.jpg',
#  '220.jpg',
#  '221.jpg',
#  '222.jpg',
#  '223.jpg',
#  '224.jpg',
#  '225.jpg',
#  '226.jpg',
#  '227.jpg',
#  '228.jpg',
#  '229.jpg',
#  '230.jpg',
#  '231.jpg',
#  '232.jpg',
#  '233.jpg',
#  '234.jpg',
#  '235.jpg',
#  '236.jpg',
#  '237.jpg',
#  '238.jpg',
#  '239.jpg']

# %%
os.listdir(r"C:\Users\laksh\Downloads\Animation")
# Out:
# ['101.jpg',
#  '102.jpg',
#  '103 - Copy.jpg',
#  '103.jpg',
#  '104.jpg',
#  '105.jpg',
#  '106.jpg',
#  '107.jpg',
#  '109.jpg',
#  '110.jpg',
#  '111.jpg',
#  '112.jpg',
#  '113.jpg',
#  '114.jpg',
#  '115.jpg',
#  '116.jpg',
#  '118.jpg',
#  '119.jpg',
#  '125.jpg',
#  '126.jpg',
#  '127.jpg',
#  '128.jpg',
#  '129.jpg',
#  '130.jpg',
#  '140.jpg',
#  '141.jpg',
#  '142.jpg',
#  '143.jpg',
#  '144.jpg',
#  '145.jpg',
#  '147.jpg',
#  '148.jpg',
#  '149.jpg',
#  '150.jpg',
#  '151.jpg',
#  '152.jpg',
#  '153.jpg',
#  '154.jpg',
#  '155.jpg',
#  '156.jpg',
#  '157.jpg',
#  '158.jpg',
#  '160.jpg',
#  '161.jpg',
#  '162.jpg',
#  '164.jpg',
#  '165.jpg',
#  '166.jpg',
#  '17.jpg',
#  '18.jpg',
#  '187.jpg',
#  '188.jpg',
#  '189.jpg',
#  '19.jpg',
#  '190.jpg',
#  '191.jpg',
#  '192.jpg',
#  '193.jpg',
#  '194.jpg',
#  '195.jpg',
#  '196.jpg',
#  '197.jpg',
#  '198.jpg',
#  '199.jpg',
#  '200.jpg',
#  '201.jpg',
#  '202.jpg',
#  '203.jpg',
#  '204.jpg',
#  '205.jpg',
#  '206.jpg',
#  '207.jpg',
#  '208.jpg',
#  '209.jpg',
#  '210.jpg',
#  '211.jpg',
#  '212.jpg',
#  '213.jpg',
#  '214.jpg',
#  '215.jpg',
#  '216.jpg',
#  '217.jpg',
#  '218.jpg',
#  '219.jpg',
#  '22.jpg',
#  '220.jpg',
#  '221.jpg',
#  '222.jpg',
#  '223.jpg',
#  '224.jpg',
#  '225.jpg',
#  '226.jpg',
#  '227.jpg',
#  '228.jpg',
#  '229.jpg',
#  '23.jpg',
#  '230.jpg',
#  '231.jpg',
#  '232.jpg',
#  '233.jpg',
#  '234.jpg',
#  '235.jpg',
#  '236.jpg',
#  '237.jpg',
#  '238.jpg',
#  '239.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '27.jpg',
#  '28.jpg',
#  '29.jpg',
#  '31.jpg',
#  '32.2.jpg',
#  '32.jpg',
#  '33.jpg',
#  '34.jpg',
#  '35.jpg',
#  '36.jpg',
#  '37.jpg',
#  '38.jpg',
#  '39 - Copy.jpg',
#  '39.jpg',
#  '40.jpg',
#  '41.3.jpg',
#  '41.4.jpg',
#  '41.jpg',
#  '42.jpg',
#  '43.jpg',
#  '58.jpg',
#  '59.jpg',
#  '60.jpg',
#  '84.jpg',
#  '85.jpg',
#  '86.jpg',
#  '87.jpg',
#  '88.jpg',
#  '89.jpg',
#  '90.jpg',
#  '91.jpg',
#  '92.jpg',
#  '93.jpg',
#  '94.jpg',
#  '95.jpg',
#  '96.jpg',
#  '97.jpg',
#  '98.2.jpg',
#  '98.3.jpg',
#  '98.4.jpg',
#  '98.jpg',
#  '99.jpg']

# %%
for images in frame_file:
    img=cv2.imread(r"C:\Users\laksh\Downloads\Animation\{}".format(images))
    cv2.imshow("animation",img)
    cv2.waitKey(20)
cv2.destroyAllWindows()

# %%
import cv2
import os

# Path to the directory containing animation frames
frame_folder = r"C:\Users\laksh\Downloads\Animation"
# List and sort the frame files (filter for .jpg images)
frames = [f for f in os.listdir(frame_folder) if f.endswith('.jpg')]
import re
frames.sort(key=lambda x: int(re.findall(r'\d+', os.path.splitext(x)[0])[0]))

# Path to save the output video
output_video_path = r"C:\Users\laksh\Downloads\Animation\output_video.mp4"

# Get the size of the first frame to define video resolution
first_frame = cv2.imread(os.path.join(frame_folder, frames[0]))
height, width, _ = first_frame.shape

# Define the codec and create the VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for .mp4 files
fps = 5  # Frames per second
out = cv2.VideoWriter(output_video_path, fourcc, fps, (width, height))

# Loop through each frame and write to the video
for image_file in frames:
    img_path = os.path.join(frame_folder, image_file)
    frame = cv2.imread(img_path)
    
    # Check if the frame is loaded correctly
    if frame is None:
        print(f"Failed to load frame: {image_file}")
        continue
    
    # Write the frame to the video
    out.write(frame)

# Release the VideoWriter and cleanup
out.release()
print(f"Video saved at: {output_video_path}")
# Out:
# Video saved at: C:\Users\laksh\Downloads\Animation\output_video.mp4

# %% [markdown]
# ### GIF

# %%
x1 = -1
y1 = -1
def mouse_tracking(event, x, y, flags, param):
    global x1, y1
    if event == 1 :
        x1 = x
        y1 = y
    elif event == 2 :
        
        #cv2.circle(img,(x,y),20,(255,255,255),-1)
#         cv2.circle(img,(x,y),40,(0,0,0),0.9)
        #cv2.circle(img,(x,y),20,(0,0,0),2)
        cv2.line(img,(x1,y1),(x,y),(0,0,255),6)
    #elif event==10:
        #cv2.circle(img,(x,y),18,(255,255,255),-1)
        #cv2.line(img,(x,y),20,(235,206,135),3)
        #cv2.line(img,(x1,y1),(x,y),(235,206,135),6)
        #cv2.line(img,(x1,y1),(x,y),(0,0,0),2)
         #cv2.rectangle(img,(x1,y1),(x,y),(18,4,89),-1)

# %%
cv2.namedWindow("mouse tracking",flags = cv2.WINDOW_FREERATIO)
cv2.setMouseCallback("mouse tracking", mouse_tracking)
c=27
black_image =  np.zeros((1000,1000,3),dtype=np.uint8)

while True:
    cv2.imshow("mouse tracking",img)
    if cv2.waitKey(1) & 255 ==ord("c"):
        cv2.imwrite(r"C:\Users\priya\Desktop\Machine Learning\projects\project1\{}.jpg".format(c),img)
        print("image is captured")
        c=c+1
    if cv2.waitKey(1) & 255 == ord("q"):
        break
cv2.destroyAllWindows()

# %%
frames = os.listdir(r"C:\Users\laksh\Downloads\gif\gif")

# %%
frames
# Out:
# ['0 .2.jpg',
#  '0.1.jpg',
#  '0.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.27.jpg',
#  '16.28.jpg',
#  '16.29.jpg',
#  '16.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg',
#  '5.jpg',
#  '6.jpg',
#  '9.jpg',
#  'output_video.mp4']

# %%
import re
frame_file = [f for f in frames if f.endswith(('.jpg'))]
frame_file.sort(key=lambda x: int(re.findall(r'\d+', os.path.splitext(x)[0])[0]))

# %%
frame_file
# Out:
# ['0 .2.jpg',
#  '0.1.jpg',
#  '0.jpg',
#  '5.jpg',
#  '6.jpg',
#  '9.jpg',
#  '10.jpg',
#  '11.jpg',
#  '12.jpg',
#  '13.jpg',
#  '14.jpg',
#  '15.jpg',
#  '16.27.jpg',
#  '16.28.jpg',
#  '16.29.jpg',
#  '16.jpg',
#  '23.jpg',
#  '24.jpg',
#  '25.jpg',
#  '26.jpg']

# %%
while True:
    for images in frame_file:
        img=cv2.imread(r"C:\Users\laksh\Downloads\gif\gif\{}".format(images))
       
        cv2.imshow("GIF",img)
        if cv2.waitKey(100) == ord("q"):
            break
        
cv2.destroyAllWindows()

# %%
"C:\Users\laksh\Downloads\gif\gif"

# %%
import cv2
import os

# Path to the directory containing animation frames
frame_folder = r"C:\Users\laksh\Downloads\gif\gif"
# List and sort the frame files (filter for .jpg images)
frames = [f for f in os.listdir(frame_folder) if f.endswith('.jpg')]
import re
frames.sort(key=lambda x: int(re.findall(r'\d+', os.path.splitext(x)[0])[0]))

# Path to save the output video
output_video_path1 = r"C:\Users\laksh\Downloads\gif\gif\output_video.mp4"

# Get the size of the first frame to define video resolution
first_frame = cv2.imread(os.path.join(frame_folder, frames[0]))
height, width, _ = first_frame.shape

# Define the codec and create the VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for .mp4 files
fps = 5  # Frames per second
out = cv2.VideoWriter(output_video_path1, fourcc, fps, (width, height))

# Loop through each frame and write to the video
for image_file in frames:
    img_path = os.path.join(frame_folder, image_file)
    frame = cv2.imread(img_path)
    
    # Check if the frame is loaded correctly
    if frame is None:
        print(f"Failed to load frame: {image_file}")
        continue
    
    # Write the frame to the video
    out.write(frame)

# Release the VideoWriter and cleanup
out.release()
print(f"Video saved at: {output_video_path1}")
# Out:
# Video saved at: C:\Users\laksh\Downloads\gif\gif\output_video.mp4
